# %%
# Helper libraries
import os
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorboard.plugins.hparams import api as hp

import IPython.display as display
from PIL import Image

# %%
# PATHS
_PATH = os.getcwd()
_DATASET = os.path.join(PATH, "chest_xray")
_TRAINING_DATA = os.path.join(DATASET, "train")
_TESTING_DATA = os.path.join(DATASET, "test")

# %% [markdown]
# INSPECT THE GIVEN DATASET

# %%
import pathlib

training = pathlib.Path(_TRAINING_DATA)
training_data_length = len(list(data_dir.glob('*/*.jpeg')))
CLASS_NAMES = np.array([item.name for item in data_dir.glob('*') if item.name != ".DS_Store"])
print(training_data_length)
print(CLASS_NAMES)
print(training)
# Out:
# 5216
# ['NORMAL' 'PNEUMONIA']
# C:\Users\Terkea\Desktop\pneumoniaX-RAY\chest_xray\train

# %%
pics = list(data_dir.glob('NORMAL/*'))

for image_path in pics[1:3]:
    display.display(Image.open(str(image_path)))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=2090x1858 at 0x1BCC8124390>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1422x1152 at 0x1BCC8124198>

# %%
# The 1./255 is to convert from uint8 to float32 in range [0,1].
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
# BATCH CONFIG
BATCH_SIZE = 32
IMG_HEIGHT = 224
IMG_WIDTH = 224
STEPS_PER_EPOCH = np.ceil(image_count/BATCH_SIZE)

# %%
# 
train_data_gen = image_generator.flow_from_directory(directory=str(data_dir),
                                                     batch_size=BATCH_SIZE,
                                                     shuffle=True,
                                                     target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                     classes = list(CLASS_NAMES))
# Out:
# Found 5216 images belonging to 2 classes.

# %% [markdown]
# BATCH SHOW

# %%
def show_batch(image_batch, label_batch):
  plt.figure(figsize=(10,10))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(image_batch[n])
      plt.title(CLASS_NAMES[label_batch[n]==1][0].title())
      plt.axis('off')

# %%
image_batch, label_batch = next(train_data_gen)
show_batch(image_batch, label_batch)

# %% [markdown]
# Load training, testing data and resize the images to 100x100

# %%
from keras.preprocessing.image import array_to_img, img_to_array, load_img

size = 100
def generate_training_data():
    images = []
    labels = []
    for label in os.listdir(TRAINING_DATA):
        _path = os.path.join(TRAINING_DATA, label)
        for image in os.listdir(_path):
            img = load_img(_path + "/" + image, target_size=(size,size))
            img = img_to_array(img)
        
            images.append(img)
            labels.append(label)
    return (images, labels)

def generate_testing_data():
    images = []
    labels = []
    for label in os.listdir(TESTING_DATA):
        _path = os.path.join(TESTING_DATA, label)
        for image in os.listdir(_path):
            img = load_img(_path + "/" + image, target_size=(size,size))
            img = img_to_array(img)
            
            images.append(img)
            labels.append(label)
    return (images, labels)
# Out:
# Using TensorFlow backend.

# %%
# Out:
# C:\Users\Terkea\Desktop\pneumoniaX-RAY\chest_xray\train
# 5215

# %%
train_data, train_labels = generate_training_data()
test_data, test_labels = generate_testing_data()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-81e6259ce439> in <module>
#       1 for image_path in train_data[:3]:
# ----> 2     display.display(Image.open(str(image_path)))
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: '[[[22. 22. 22.]\n  [18. 18. 18.]\n  [25. 25. 25.]\n  ...\n  [94. 94. 94.]\n  [93. 93. 93.]\n  [93. 93. 93.]]\n\n [[19. 19. 19.]\n  [20. 20. 20.]\n  [14. 14. 14.]\n  ...\n  [96. 96. 96.]\n  [93. 93. 93.]\n  [90. 90. 90.]]\n\n [[20. 20. 20.]\n  [19. 19. 19.]\n  [15. 15. 15.]\n  ...\n  [94. 94. 94.]\n  [91. 91. 91.]\n  [88. 88. 88.]]\n\n ...\n\n [[29. 29. 29.]\n  [29. 29. 29.]\n  [29. 29. 29.]\n  ...\n  [21. 21. 21.]\n  [23. 23. 23.]\n  [24. 24. 24.]]\n\n [[30. 30. 30.]\n  [27. 27. 27.]\n  [27. 27. 27.]\n  ...\n  [44. 44. 44.]\n  [47. 47. 47.]\n  [46. 46. 46.]]\n\n [[38. 38. 38.]\n  [36. 36. 36.]\n  [36. 36. 36.]\n  ...\n  [86. 86. 86.]\n  [88. 88. 88.]\n  [91. 91. 91.]]]'

# %% [markdown]
# Encode  the labels for training and testing

# %%
from sklearn.preprocessing import LabelBinarizer
encoder = LabelBinarizer()
train_labels = encoder.fit_transform(train_labels)
test_labels = encoder.fit_transform(test_labels)

# %% [markdown]
# Define the parameters for optimization and log each run

# %%
EPOCHS = hp.HParam('epochs', hp.IntInterval(10,15))
NEURONS = hp.HParam('neurons', hp.Discrete([128, 256, 512]))
DROPOUT = hp.HParam('dropout', hp.RealInterval(0.1, 0.2))
OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['Adam', 'SGD']))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
  hp.hparams_config(
    hparams=[NEURONS, DROPOUT, OPTIMIZER, EPOCHS],
    metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
  )

# %% [markdown]
# generate model based on the hparams defined previously

# %%
def train_test_model(hparams):     
    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(hparams[NEURONS], activation=tf.nn.relu),
        tf.keras.layers.Dropout(hparams[DROPOUT]),
        tf.keras.layers.Dense(2),
    ])

    model.compile(
        optimizer=hparams[OPTIMIZER],
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy'],
    )

    model.fit(np.array(train_data), train_labels, epochs=hparams[EPOCHS])
    _, accuracy = model.evaluate(np.array(test_data),test_labels)
    return accuracy

# %% [markdown]
# Index model based on accuracy gained and params used

# %%
def run(run_dir, hparams):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)
        accuracy = train_test_model(hparams)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %% [markdown]
# Generate all possible models from combinations of the defined parameters

# %%
session_num = 265
for epoch in range(EPOCHS.domain.min_value, EPOCHS.domain.max_value):
    for neurons in NEURONS.domain.values:
        for dropout_rate in (DROPOUT.domain.min_value, DROPOUT.domain.max_value):
            for optimizer in OPTIMIZER.domain.values:
                hparams = {
                    NEURONS: neurons,
                    DROPOUT: dropout_rate,
                    OPTIMIZER: optimizer,
                    EPOCHS: epoch
                }
                run_name = f"run-{session_num}_{epoch}_{neurons}_{dropout_rate}_{optimizer}"
                print('--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                run('logs/hparam_tuning/' + run_name, hparams)
                session_num += 1
